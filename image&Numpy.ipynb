# %% [markdown]
# dfd

# %%
from PIL import Image

# %%
img= Image.open("aaa.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=403x444 at 0x7FB1676E81D0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
imgarray = np.asarray(img)

# %%
type(imgarray)
# Out:
# numpy.ndarray

# %%
imgarray.shape
# Out:
# (444, 403, 3)

# %%
imgarray.ravel()
# Out:
# array([216, 219, 224, ..., 215, 210, 170], dtype=uint8)

# %%
imgarray.shape
# Out:
# (444, 403, 3)
